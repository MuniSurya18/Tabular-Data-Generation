# %% [markdown]
# # DSDDPM: Dual-Scale Diffusion Probabilistic Model
# Running the Tabular Data Generation model on Google Colab.

# %%
# 1. Clone the Repository (Force Clean Start)
# Removes existing folder to ensure we get the latest code fixes
import os
if os.path.exists('Tabular-Data-Generation'):
    # !rm -rf Tabular-Data-Generation

# !git clone https://github.com/MuniSurya18/Tabular-Data-Generation.git
# %cd Tabular-Data-Generation

# %%
# 2. Install Dependencies
# !pip install -r requirements.txt

# %%
# 3. Run the App (Using LocalTunnel)
# Note: Ngrok often requires an auth token now, so we use LocalTunnel.

# 1. Install LocalTunnel
# !npm install -g localtunnel

# 2. Run Streamlit in the Background
print("Starting Streamlit...")
get_ipython().system_raw('streamlit run web/app.py &')

# 3. Get the Password (IP Address)
print("\n==================================================")
print("COPY THIS IP ADDRESS for the password: ")
# !curl ipv4.icanhazip.com
print("==================================================\n")

# 4. Start the Tunnel
print("Click the url below and enter the IP address from above:")
# !npx localtunnel --port 8501

# %%
# Alternative: Run manually if you prefer script over UI
# !python scripts/generate_synthetic.py
# !python -m src.train --data data/dummy.csv --epochs 50
# !python -m src.sample --model checkpoints/model_final.pt --data data/dummy.csv --num_samples 100
